# %% [markdown]
# # RA2CE Notebook to get graphs and perform  hazard overlay

# %% [markdown]
# Do your imports

# %%
# === Standard Library ===
from pathlib import Path
import pickle

# === Scientific & Data Libraries ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm


# === Geospatial Libraries ===
import geopandas as gpd
import rasterio
import folium
from shapely.geometry import box, Point, LineString, Polygon, shape
from pyproj import Transformer
import networkx as nx
import geohexgrid as ghg
from shapely.ops import transform


# === RA2CE Project Imports ===
from ra2ce.network.network_config_data.enums.aggregate_wl_enum import AggregateWlEnum
from ra2ce.network.network_config_data.enums.source_enum import SourceEnum
from ra2ce.network.network_config_data.enums.network_type_enum import NetworkTypeEnum
from ra2ce.network.network_config_data.enums.road_type_enum import RoadTypeEnum
from ra2ce.network.network_config_data.network_config_data import (
    HazardSection,
    NetworkConfigData,
    NetworkSection,
    OriginsDestinationsSection
)
from ra2ce.network.exporters.geodataframe_network_exporter import GeoDataFrameNetworkExporter
from ra2ce.network.exporters.multi_graph_network_exporter import MultiGraphNetworkExporter
from ra2ce.network.network_wrappers.osm_network_wrapper.osm_network_wrapper import OsmNetworkWrapper
from ra2ce.ra2ce_handler import Ra2ceHandler

import os
from pathlib import Path

# %%
# specify the name of the path to the project folder where you created the RA2CE folder setup

root_dir = Path(r'N:\Projects\11209000\11209175\B. Measurements and calculations\Data\full_run\V_K_analyse')
#root_dir = Path.cwd().parent.joinpath("data")
assert root_dir.exists()
static_path = root_dir.joinpath("static_maxwd_diff_region")
network_path = static_path.joinpath("network")
output_path = static_path.joinpath("output_graph")
hazard_path = static_path.joinpath("hazard", "reprojected")

# %% [markdown]
# ## Find the study area

# %%
# some preliminary functions

def get_all_files(directory: str) -> list[Path]:
    p = Path(directory)
    return [file for file in p.iterdir() if file.is_file()]

def read_pickle(file_path: str):
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data

def read_gpkg_to_gdf(file_path: str, layer: str = None) -> gpd.GeoDataFrame:
    # Read the geopackage file into a GeoDataFrame
    gdf = gpd.read_file(file_path, layer=layer)
    return gdf

# %%
hazard_files = get_all_files(hazard_path)
hazard_crs = "EPSG:4326" 

for hazard_file in hazard_files:
    print (hazard_file)
# Out:
# N:\Projects\11209000\11209175\B. Measurements and calculations\Data\full_run\V_K_analyse\static_maxwd_diff_region\hazard\reprojected\samengevoegd_max_inundatiediepte_5m_wgs84.tif

# %%
import rasterio
from shapely.geometry import box

# Path to your GeoTIFF file
geotiff_path = hazard_file

# Open the GeoTIFF and get its bounds
with rasterio.open(geotiff_path) as src:
    bounds = src.bounds
    crs = src.crs  # Coordinate Reference System

# Create a Shapely polygon from the bounds
bbox_polygon = box(bounds.left, bounds.bottom, bounds.right, bounds.top)
gdf_polygon = gpd.GeoDataFrame({'geometry': [bbox_polygon]}, crs=crs)

# Print the polygon and CRS
print("Bounding Box Polygon:", bbox_polygon)
print("CRS:", crs)
# Out:
# Bounding Box Polygon: POLYGON ((6.226501684064556 51.94519109585251, 6.226501684064556 52.52305864938243, 5.207261495988784 52.52305864938243, 5.207261495988784 51.94519109585251, 6.226501684064556 51.94519109585251))
# CRS: EPSG:4326

# %%
gdf_polygon.to_file(network_path.joinpath("polygon.geojson"), driver='GeoJSON')

# %% [markdown]
# # RA2CE

# %% [markdown]
# ### Let us first initalize and perform the ra2ce run so we have all the data that we need

# %% [markdown]
# #### Cutting RoadTypeEnum.MOTORWAY,RoadTypeEnum.MOTORWAY_LINK to make analysis more realistic

# %%
gdf_polygon_path = network_path.joinpath("polygon.geojson")

# %%
_network_section = NetworkSection(
    network_type=NetworkTypeEnum.DRIVE,
    source=SourceEnum.OSM_DOWNLOAD,
    polygon=gdf_polygon_path, #it needs a path without the list!
    save_gpkg=True,
    road_types=[RoadTypeEnum.MOTORWAY, RoadTypeEnum.MOTORWAY_LINK, RoadTypeEnum.PRIMARY, RoadTypeEnum.PRIMARY_LINK,RoadTypeEnum.TRUNK, RoadTypeEnum.SECONDARY,RoadTypeEnum.SECONDARY_LINK, RoadTypeEnum.TERTIARY, RoadTypeEnum.RESIDENTIAL, RoadTypeEnum.UNCLASSIFIED], 
    attributes_to_exclude_in_simplification=['bridge', 'tunnel'],
)

# Make the NetworkConfigData
_hazard_section = HazardSection(
    hazard_map=hazard_files,
    hazard_id=None,
    hazard_field_name="waterdepth",
    aggregate_wl=None,
    hazard_crs=hazard_crs,
    overlay_segmented_network = True
)

_network_config_data = NetworkConfigData(
    root_path=root_dir,
    static_path=static_path,
    #output_path=output_path,
    network=_network_section,
    hazard=_hazard_section)

# %%
# Run analysis
_handler = Ra2ceHandler.from_config(_network_config_data, analysis=None)
_handler.configure()
# Out:
# c:\Users\meije_le\AppData\Local\miniforge3\envs\ra2ce_env\Lib\site-packages\osmnx\simplification.py:513: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = convert.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# c:\Users\meije_le\AppData\Local\miniforge3\envs\ra2ce_env\Lib\site-packages\osmnx\simplification.py:560: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Run analysis
#       2 _handler = Ra2ceHandler.from_config(_network_config_data, analysis=None)
# ----> 3 _handler.configure()
#
# File C:\python\ra2ce\ra2ce\ra2ce_handler.py:152, in Ra2ceHandler.configure(self)
#     146 def configure(self) -> None:
#     147     """
#     148     Configures the `ConfigWrapper` with the current `AnalysisConfigData` and
#     149     `NetworkConfigData` so that the analyses can be succesfully run. This method will generate files of the network in the folder
#     150     output_graph if they do not yet exist. This method can also be run if AnalysisConfigData is None.
#     151     """
# --> 152     self.input_config.configure()
#     153     self.analysis_collection = AnalysisCollection.from_config(
#     154         self.input_config.analysis_config
#     155     )
#
# File C:\python\ra2ce\ra2ce\configuration\config_wrapper.py:72, in ConfigWrapper.configure(self)
#      70 def configure(self) -> None:
#      71     if self.network_config:
# ---> 72         self.network_config.configure()
#      73     if self.analysis_config:
#      74         self.analysis_config.configure()
#
# File C:\python\ra2ce\ra2ce\network\network_config_wrapper.py:84, in NetworkConfigWrapper.configure(self)
#      83 def configure(self) -> None:
# ---> 84     self.configure_network()
#      85     self.configure_hazard()
#
# File C:\python\ra2ce\ra2ce\network\network_config_wrapper.py:89, in NetworkConfigWrapper.configure_network(self)
#      87 def configure_network(self) -> None:
#      88     network = Network(self.config_data, self.graph_files)
# ---> 89     self.graph_files = network.create()
#
# File C:\python\ra2ce\ra2ce\network\networks.py:230, in Network.create(self)
#     228 # For all graph and networks - check if it exists, otherwise, make the graph and/or network.
#     229 if not (self.graph_files.base_graph.file or self.graph_files.base_network.file):
# --> 230     self._get_new_network_and_graph(to_save)
#     231 else:
#     232     self._get_stored_network_and_graph()
#
# File C:\python\ra2ce\ra2ce\network\networks.py:177, in Network._get_new_network_and_graph(self, export_types)
#     167 def _get_new_network_and_graph(self, export_types: list[str]) -> None:
#     168     """
#     169     TODO: This method should be relying on a generic definition of a network result
#     170     from `.get_network`. This means, instead of getting `_base_graph, _network_gdf`
#     171     we get a generic `_ra2ce_network_wrapper` from which can later on just do a
#     172     `.simplify_network` or `.add_eges`, etc. using inheritance.
#     173     """
#     175     _base_graph, _network_gdf = NetworkWrapperFactory(
#     176         self._config_data
# --> 177     ).get_network()
#     179     self.base_graph_crs = _network_gdf.crs
#     180     self.base_network_crs = _network_gdf.crs
#
# File C:\python\ra2ce\ra2ce\network\network_wrappers\network_wrapper_factory.py:65, in NetworkWrapperFactory.get_network(self)
#      63     return TrailsNetworkWrapper(self._config_data).get_network()
#      64 elif source == SourceEnum.OSM_DOWNLOAD:
# ---> 65     return OsmNetworkWrapper(self._config_data).get_network()
#      66 elif source == SourceEnum.PICKLE:
#      67     logging.info("Start importing a network from pickle")
#
# File C:\python\ra2ce\ra2ce\network\network_wrappers\osm_network_wrapper\osm_network_wrapper.py:149, in OsmNetworkWrapper.get_network(self)
#     143 def get_network(self) -> tuple[MultiGraph, GeoDataFrame]:
#     144
#     145     # Create 'graph_simple'
#     146     graph_simple, graph_complex, link_tables = NetworkGraphSimplificator(
#     147         graph_complex=self.polygon_graph,
#     148         attributes_to_exclude=self.attributes_to_exclude_in_simplification,
# --> 149     ).simplify()
#     151     # Assign the average speed and time to the graphs
#     152     graph_simple = AvgSpeedCalculator(
#     153         graph_simple, self.link_type_column, self.output_graph_dir
#     154     ).assign()
#
# File C:\python\ra2ce\ra2ce\network\network_simplification\network_graph_simplificator.py:61, in NetworkGraphSimplificator.simplify(self)
#      57 try:
#      58     _graph_complex = self._graph_create_unique_ids(
#      59         self.graph_complex, "{}_c".format(self.new_id)
#      60     )
# ---> 61     _graph_simple = self._get_graph_simple()
#      63     # Create look_up_tables between graphs with unique ids
#      64     (
#      65         _simple_to_complex,
#      66         _complex_to_simple,
#      67     ) = self._graph_link_simple_id_to_complex(_graph_simple)
#
# File C:\python\ra2ce\ra2ce\network\network_simplification\network_graph_simplificator.py:86, in NetworkGraphSimplificator._get_graph_simple(self)
#      81 def _get_graph_simple(self) -> NxGraph:
#      82     if any(self.attributes_to_exclude):
#      83         _graph_simple = NetworkSimplificationWithAttributeExclusion(
#      84             nx_graph=self.graph_complex,
#      85             attributes_to_exclude=self.attributes_to_exclude,
# ---> 86         ).simplify_graph()
#      87     else:
#      88         self.graph_complex = (
#      89             self.graph_complex.to_directed()
#      90         )  # simplification function requires nx.MultiDiGraph
#
# File C:\python\ra2ce\ra2ce\network\network_simplification\network_simplification_with_attribute_exclusion.py:53, in NetworkSimplificationWithAttributeExclusion.simplify_graph(self)
#      39 """
#      40 Simplifies the inner graph by using the `snkit` package.
#      41
#      42 Returns:
#      43     nx.Graph: Resulting simplified graph.
#      44 """
#      45 _snkit_network_wrapper = SnkitNetworkWrapper.from_networkx(
#      46     self.nx_graph,
#      47     column_names_dict=dict(
#    (...)
#      51     ),
#      52 )
# ---> 53 _snkit_network_wrapper.merge_edges(self.attributes_to_exclude)
#      54 _snkit_network_wrapper.process_network()
#      55 return _snkit_network_wrapper.to_networkx()
#
# File C:\python\ra2ce\ra2ce\network\network_simplification\snkit_network_wrapper.py:104, in SnkitNetworkWrapper.merge_edges(self, attributes_to_exclude)
#      99     _aggregate_function = self._aggrfunc(
#     100         cols, _attributes_to_exclude, with_demand=False
#     101     )
#     103 # Overwrite the existing network with the merged edges.
# --> 104 self.snkit_network = merge_edges(
#     105     snkit_network=self.snkit_network,
#     106     networkx_graph=self.to_networkx(),
#     107     aggregate_func=_aggregate_function,
#     108     by=_attributes_to_exclude,
#     109     id_col="id",
#     110 )
#
# File C:\python\ra2ce\ra2ce\network\network_simplification\snkit_network_merge_wrapper.py:261, in merge_edges(snkit_network, networkx_graph, aggregate_func, by, id_col)
#     257 filtered_degree_4_set = filter_node(degree_4_set, _degrees=4)
#     259 nodes_of_interest = filtered_degree_2_set | filtered_degree_4_set
# --> 261 edge_paths = get_edge_paths(sorted(nodes_of_interest), snkit_network)
#     263 edge_ids_to_update = get_edge_ids_to_update(edge_paths)
#     264 edges_to_keep = snkit_network.edges[
#     265     ~snkit_network.edges["id"].isin(edge_ids_to_update)
#     266 ]
#
# File C:\python\ra2ce\ra2ce\network\network_simplification\snkit_network_merge_wrapper.py:232, in merge_edges.<locals>.get_edge_paths(node_set, _snkit_network)
#     228             _edge_paths = find_and_append_degree_4_paths(_edge_paths)
#     229         else:
#     230             # node_path has nodes with degree 2 => find the edges connected to the intermediates
#     231             edge_paths_gdf = snkit_network.edges[
# --> 232                 snkit_network.edges.from_id.isin(intermediates)
#     233                 | snkit_network.edges.to_id.isin(intermediates)
#     234             ]
#     235             _edge_paths.append(edge_paths_gdf)
#     236 return _edge_paths
#
# File c:\Users\meije_le\AppData\Local\miniforge3\envs\ra2ce_env\Lib\site-packages\pandas\core\series.py:5563, in Series.isin(self, values)
#    5490 def isin(self, values) -> Series:
#    5491     """
#    5492     Whether elements in Series are contained in `values`.
#    5493
#    (...)
#    5561     dtype: bool
#    5562     """
# -> 5563     result = algorithms.isin(self._values, values)
#    5564     return self._constructor(result, index=self.index).__finalize__(
#    5565         self, method="isin"
#    5566     )
#
# File c:\Users\meije_le\AppData\Local\miniforge3\envs\ra2ce_env\Lib\site-packages\pandas\core\algorithms.py:527, in isin(comps, values)
#     524     comps_array = comps_array.astype(common, copy=False)
#     525     f = htable.ismember
# --> 527 return f(comps_array, values)
#
# KeyboardInterrupt:

# %%
# # Create base_graph_hazard_editted
# from grid_based_accessibility_hex import read_pickle
# import pickle 

# input_graph = Path(r'C:\repos\powerpath\data\static\output_graph\base_graph_hazard.p')
# output_graph = Path(r'C:\repos\powerpath\data\static\output_graph\base_graph_hazard_editted.p')
# if not output_graph.exists():
#     base_graph = read_pickle(input_graph)
#     base_graph_hazard_editted = base_graph.copy()

# # Add column EV0_ma and set to 0.0, also set EV6-9 to 0.0
# for i in range(10):
#     col_name = f'EV{i}_ma'
    
#     # For NetworkX graphs, we need to add attributes to each edge
#     for u, v, key in base_graph_hazard_editted.edges(keys=True):
#         # Check if the attribute exists on any edge, if not add it
#         if col_name not in base_graph_hazard_editted[u][v][key]:
#             base_graph_hazard_editted[u][v][key][col_name] = 0.0
        
#         # Set EV6-9 to 0.0
#         if i >= 6:
#             base_graph_hazard_editted[u][v][key][col_name] = 0.0

# for u,v,d in base_graph_hazard_editted.edges(data=True):
#     print (d['EV0_ma'], d['EV1_ma'], d['EV2_ma'], d['EV3_ma'], d['EV4_ma'], d['EV5_ma'], d['EV6_ma'], d['EV7_ma'], d['EV8_ma'], d['EV9_ma'])

# pickle.dump(base_graph_hazard_editted, open(output_graph, 'wb'))  # Save the modified graph
#     # Save the modified graph
